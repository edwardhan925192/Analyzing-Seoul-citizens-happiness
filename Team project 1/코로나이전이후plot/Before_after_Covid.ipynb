# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardhan925192/Python_grammar/blob/main/Team%20project%201/%EC%BD%94%EB%A1%9C%EB%82%98%EC%9D%B4%EC%A0%84%EC%9D%B4%ED%9B%84plot/Before_after_Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('/content/drive/MyDrive/data/행복도 데이터/newest_seoulsurvey.csv')

# %%
df_happiness = pd.DataFrame(df.groupby(['year'])['행복지수(가정생활)'].mean())

# %%
fig = plt.figure(figsize = (10,10))
df_happiness.plot(kind = 'bar')
# Out:
# <Axes: xlabel='year'>
